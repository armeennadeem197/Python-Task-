# %% [markdown]
# <a href="https://colab.research.google.com/github/armeennadeem197/Python-Task-/blob/main/python_task_1_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1: Cinema Ticket Price

user_name = input ("Enter you name: ")
age = int (input ("Enter you age: "))

if age < 5 or age > 100:
  ticket_price = 0

elif age >= 5 and age <= 12 :
  ticket_price = 300

elif age >= 13 and age <= 59:
  ticket_price = 700

else :
  ticket_price = 400

print("Customer Name: " , user_name)
print("Ticket Price: " "Rs: " , ticket_price)
# Out:
# Enter you name: aimen
# Enter you age: 12
# Customer Name:  aimen
# Ticket Price: Rs:  300

# %%
#Task 2: Temperature Converter

Celsius_temperature = int (input ("Enter Celsius temperature: "))

Fahrenheit = (Celsius_temperature  * 9/5) + 32

if Celsius_temperature <10 :
    whether_condition = "Very Cold"

elif Celsius_temperature >= 10 and Celsius_temperature <= 19 :
  whether_condition ="Cold"

elif Celsius_temperature >= 20 and Celsius_temperature <= 29 :
  whether_condition ="Normal"
else:
  whether_condition ="Hot"

print(whether_condition)
print(Fahrenheit)
# Out:
# Enter Celsius temperature: 6
# Very Cold
# 42.8

# %%
#Task 3: Mobile Recharge Calculator

user = int (input("Enter mobile number: "))
recharge_amount = int (input("Enter recharge_amount: "))

tax = recharge_amount * 3 / 100
Final_balance = recharge_amount - tax

print ("Final Balance:" , Final_balance)
# Out:
# Enter mobile number: 03130287890
# Enter recharge_amount: 500
# Final Balance: 485.0

# %%
#Task 4: Weekly Steps Tracker

total_steps = 0

for i in range(1, 8):
    user_input = int(input("Enter your steps: "))
    total_steps = total_steps + user_input

average_step = total_steps / 7

print("Total Steps:", total_steps)
print("Average Steps:", average_step)

if average_step >= 5000:

    print("Active Week")
else:
    print("Needs More Activity")
# Out:
# Enter your steps: 4000
# Enter your steps: 5000
# Enter your steps: 3000
# Enter your steps: 6000
# Enter your steps: 7000
# Enter your steps: 4000
# Enter your steps: 9000
# Total Steps: 38000
# Average Steps: 5428.571428571428
# Active Week

# %%
#Task 5: Secure PIN Checker

secret_pin = 1234

for i in range(1, 4):

    user_input = int(input("Enter your secret PIN: "))

    if user_input == secret_pin:
        print("Access Granted")
        break

    else:
        remaining_attempts = 3 - i
        print("Access Denied")
        print("Remaining attempts:", remaining_attempts)

        if i == 3:
            print("Account Blocked")
# Out:
# Enter your secret PIN: 44444
# Access Denied
# Remaining attempts: 2
# Enter your secret PIN: 5555
# Access Denied
# Remaining attempts: 1
# Enter your secret PIN: 6666
# Access Denied
# Remaining attempts: 0
# Account Blocked
